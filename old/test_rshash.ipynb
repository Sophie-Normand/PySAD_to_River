# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\e32cl\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\e32cl\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\e32cl\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import scipy.io

# %%
#data = scipy.io.loadmat('/Users/Sophie/Library/CloudStorage/OneDrive-Personnel/IP/Data Stream Processing/PySAD_to_River/data/arrhythmia.mat') 
data = scipy.io.loadmat('C:/Users/e32cl/Documents/M2/P2 Data Stream/Projet/PySAD_to_River/data/arrhythmia.mat')

# %%
X = data['X']
y = data['y']
y_flat = data['y'].flatten()

# %%
y.mean()
# Out:
# 0.14601769911504425

# %%
X[:100].min(axis=0)
# Out:
# array([ 1.000e+00,  0.000e+00,  1.100e+02,  1.000e+01,  6.900e+01,
#         0.000e+00,  2.410e+02,  1.130e+02,  0.000e+00, -1.370e+02,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00,
#         0.000e+00,  0.000e+00,  0.000e+00,  0.000e+00, -2.700e+00,
#        -2.100e+00,  0.000e+00, -6.600e+00,  0.000e+00,  0.000e+00,
#        -4.000e-01, -1.800e+00, -1.170e+01, -1.800e+01, -1.700e+00,
#        -3.400e+00,  0.000e+00, -5.800e+00,  0.000e+00,  0.000e+00,
#        -5.000e-01, -2.700e+00, -2.090e+01, -1.760e+01, -1.300e+00,
#        -1.060e+01,  0.000e+00, -1.410e+01,  0.000e+00,  0.000e+00,
#        -1.000e+00, -1.600e+00, -4.690e+01, -5.290e+01, -1.000e+00,
#        -1.280e+01,  0.000e+00, -1.220e+01,  0.000e+00,  0.000e+00,
#        -1.600e+00, -3.400e+00, -4.600e+01, -5.920e+01, -2.100e+00,
#        -3.800e+00,  0.000e+00, -1.290e+01,  0.000e+00,  0.000e+00,
#        -6.000e-01, -1.800e+00, -3.870e+01, -4.210e+01, -1.700e+00,
#        -5.500e+00,  0.000e+00, -9.800e+00,  0.000e+00,  0.000e+00,
#        -2.000e-01, -1.500e+00, -3.430e+01, -3.520e+01, -8.000e-01,
#        -1.830e+01,  0.000e+00, -2.440e+01,  0.000e+00, -4.000e-01,
#        -2.100e+00, -3.300e+00, -8.740e+01, -5.990e+01, -9.000e-01,
#        -2.960e+01,  0.000e+00, -4.330e+01,  0.000e+00,  0.000e+00,
#        -2.300e+00, -2.700e+00, -1.953e+02, -9.510e+01, -1.700e+00,
#        -2.230e+01,  0.000e+00, -4.840e+01,  0.000e+00, -5.000e-01,
#        -3.100e+00, -5.200e+00, -2.424e+02, -7.630e+01, -2.900e+00,
#        -1.660e+01,  0.000e+00, -2.840e+01,  0.000e+00,  0.000e+00,
#        -7.000e-01, -3.100e+00, -1.183e+02, -5.270e+01, -1.600e+00,
#        -7.700e+00,  0.000e+00, -1.140e+01,  0.000e+00,  0.000e+00,
#        -6.000e-01, -3.000e+00, -3.380e+01, -1.630e+01, -4.500e+00,
#        -2.100e+00,  0.000e+00, -4.800e+00,  0.000e+00,  0.000e+00,
#        -3.000e-01, -3.700e+00, -8.300e+00, -3.860e+01])

# %%
X.max(axis=0)
# Out:
# array([ 83. ,   1. , 780. , 176. , 188. , 524. , 509. , 381. , 205. ,
#        169. ,  88. , 156. ,  88. ,  24. ,   0. , 100. ,   1. ,   1. ,
#          1. ,   1. ,   1. ,   1. ,  76. , 132. ,  92. ,  36. ,  56. ,
#         76. ,   1. ,   1. ,   1. ,   1. ,   1. ,   1. ,  92. , 116. ,
#        132. ,  64. ,  44. ,  92. ,   1. ,   1. ,   1. ,   1. ,   1. ,
#          1. , 136. ,  80. ,  80. ,  84. ,  32. ,  92. ,   1. ,   1. ,
#          1. ,   1. ,   1. ,   1. ,  88. , 148. ,  92. ,  44. ,   0. ,
#         96. ,   0. ,   1. ,   1. ,   1. ,   1. ,   1. ,  88. , 128. ,
#        120. ,  44. ,  44. ,  80. ,   1. ,   1. ,   0. ,   1. ,   1. ,
#          1. , 140. , 216. , 116. ,  80. ,  28. , 116. ,   1. ,   1. ,
#          1. ,   1. ,   1. ,   1. , 132. , 216. , 108. ,  72. ,  32. ,
#         96. ,   1. ,   1. ,   1. ,   1. ,   1. ,   1. ,  96. , 132. ,
#        112. ,  76. ,  36. ,  88. ,   1. ,   1. ,   1. ,   1. ,   1. ,
#          1. ,  88. ,  92. , 124. ,  24. ,  40. ,  60. ,   1. ,   1. ,
#          0. ,   0. ,   1. ,   1. ,  88. , 136. , 120. ,  60. ,   0. ,
#        132. ,   0. ,   1. ,   0. ,   1. ,   0. ,   1. ,  88. , 148. ,
#        108. ,  28. ,   0. , 104. ,   1. ,   1. ,   1. ,   0. ,   0. ,
#          1. ,   1.4,   0. ,  19.9,   0. ,   1.9,   0. ,   1.7,   3.7,
#        155.2,  74.3,   1.9,   0. ,  19.2,   0. ,   3.2,   0. ,   3.4,
#          7.2,  64.6,  87.1,   5.1,   0. ,  21.7,   0. ,  14.9,   0. ,
#          2.2,   7.1,  66.7,  95.8,   6.4,   0. ,  11.8,   0. ,   3.5,
#          0. ,   1.3,   6.4,  26.3,  10.7,   2.6,   0. ,  15.6,   0. ,
#          2.3,   0. ,   2. ,   5.1, 115.4,  46.1,   2.5,   0. ,  19.9,
#          0. ,   9.1,   0. ,   2.7,   7. ,  64.2,  69.1,  16.6,   0. ,
#         26. ,   0. ,  19.2,   0. ,   1.8,  16.7, 268.9, 247.1,  10. ,
#          0. ,  28.5,   0. ,  14.9,   0. ,   3.3,  13.2, 133.9, 123.6,
#         15.1,   0. ,  28.4,   0. ,   7. ,   0. ,   2.5,  18.8, 165.4,
#        137.8,   9.7,   0. ,  36.4,   0. ,   2.4,   0. ,   2.8,  15.6,
#        103.4, 182.3,   3.4,   0. ,  29.5,   0. ,   5.8,   0. ,   2.8,
#          8.3,  82.1, 127.9,   2.7,   0. ,  23.6,   0. ,   0.8,   0. ,
#          2.4,   6. ,  88.8, 115.9])

# %%
np.ones((274,))*500
# Out:
# array([500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500., 500.,
#        500., 500., 500., 500., 500., 500., 500., 500., 500., 500.])

# %%
from anomaly.base import AnomalyDetector

# %%
from river import metrics

# %%
from models.rs_hash import RSHash

# %%
from river.stream import iter_array

# %% [markdown]
# # Test Dico

# %%
model = RSHash(X[:100].min(axis=0),X[:100].max(axis=0))
ROCAUC = metrics.ROCAUC()
for xi, yi in iter_array(X,y_flat):
    
    model = model.learn_one(xi)
    anomaly_score = model.score_one(xi)
    
    ROCAUC.update(yi,anomaly_score)
print(ROCAUC)
# Out:
# ROCAUC: 25.28%

# %%
from pysad.evaluation import AUROCMetric

# %%
model = RSHash(X[:100].min(axis=0),X[:100].max(axis=0))
ROCAUC1 = AUROCMetric()
for xi, yi in iter_array(X,y_flat):
    
    model = model.learn_one(xi)
    anomaly_score = model.score_one(xi)
    
    ROCAUC1.update(yi,anomaly_score)
print(ROCAUC1.get())
# Out:
# 0.2934919139582352

# %% [markdown]
# # OLD VERSION

# %%
model = RSHash(X.min(axis=0),X.max(axis=0))
ROCAUC = metrics.ROCAUC()
for xi, yi in iter_array(X,y):
    x_array = np.array(list(xi.values()))
    y_array = np.array(list(yi.values()))
    model = model.learn_one(x_array)           #pas dans le bon sens pour river
    anomaly_score = model.score_one(x_array)   #A FAIRE: il faut que anomaly_score soit entre 1 et 0 pour river
    
#    print(y_array,anomaly_score)
    ROCAUC.update(int(y_array[0]),anomaly_score)
print(ROCAUC)
# Out:
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# (274,)
# ROCAUC: 26.95%

# %% [markdown]
# ROCAUC: 28.52%
# le modèle ne semble rien apprendre !

# %%
from pysad.evaluation import AUROCMetric

# %%
model = RSHash(X.min(axis=0),X.max(axis=0))
ROCAUC = AUROCMetric()
for xi, yi in iter_array(X,y):
    x_array = np.array(list(xi.values()))
    y_array = np.array(list(yi.values()))
    model = model.learn_one(x_array)           #pas dans le bon sens pour river
    anomaly_score = model.score_one(x_array)   #A FAIRE: il faut que anomaly_score soit entre 1 et 0 pour river
    
#    print(y_array,anomaly_score)
    ROCAUC.update(int(y_array[0]),anomaly_score)
print(ROCAUC.get())
# Out:
# 0.24945046318103312

# %%
from pysad.transform.probability_calibration import ConformalProbabilityCalibrator

# %%
model = RSHash(X.min(axis=0),X.max(axis=0))
calibrator = ConformalProbabilityCalibrator(windowed=True, window_size=300)
ROCAUC = AUROCMetric()
for xi, yi in iter_array(X,y):
    x_array = np.array(list(xi.values()))
    y_array = np.array(list(yi.values()))
    model = model.learn_one(x_array)           #pas dans le bon sens pour river
    anomaly_score = model.score_one(x_array)   #A FAIRE: il faut que anomaly_score soit entre 1 et 0 pour river
    calibrated_score = calibrator.fit_transform(anomaly_score)
#    print(y_array,anomaly_score)
    ROCAUC.update(int(y_array[0]),calibrated_score)
print(ROCAUC.get())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-6a5217609638> in <module>
#       7     model = model.learn_one(x_array)           #pas dans le bon sens pour river
#       8     anomaly_score = model.score_one(x_array)   #A FAIRE: il faut que anomaly_score soit entre 1 et 0 pour river
# ----> 9     calibrated_score = calibrator.fit_transform(anomaly_score)
#      10 #    print(y_array,anomaly_score)
#      11     ROCAUC.update(int(y_array[0]),calibrated_score)
#
# /opt/anaconda3/lib/python3.8/site-packages/pysad/core/base_postprocessor.py in fit_transform(self, scores)
#      81             np.float array of shape (num_instances,): Processed scores.
#      82         """
# ---> 83         processed_scores = np.empty(scores.shape[0], dtype=np.float)
#      84         for i, (score, _) in enumerate(_iterate(scores)):
#      85             processed_scores[i] = self.fit_transform_partial(score)
#
# IndexError: tuple index out of range
